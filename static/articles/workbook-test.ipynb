# %% [markdown]
# ## Example Workbook
#
# Below is a simple workboook to create a dataframe and associated plot.

# %% [markdown]
# Let' start by creating a dataframe using the python library `pandas`:

# %%
import numpy as np
import pandas as pd

# Create a DataFrame

df = pd.DataFrame({
    'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
    'Atitlan': np.random.randn(8),
    'Consulting': np.random.randn(8)
})

df.head()
# Out:
#      A      B   Atitlan  Consulting
# 0  foo    one -0.081101   -0.268691
# 1  bar    one  0.396183    1.059515
# 2  foo    two -0.687674   -1.315925
# 3  bar  three  0.053742    2.093905
# 4  foo    two -0.657771    1.172652

# %%
# Plot using MAtplotlib and Raleway font

import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rc('font', family='Raleway')

df.plot()
# Out:
# <Axes: >
